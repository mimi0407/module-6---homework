# %%
import pandas as pd
import numpy as np

# %%
Location = 'kc_house_data.csv'
df=pd.read_csv(Location)

df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
import statsmodels.formula.api as smf

# %%
result = smf.ols ('grade ~ price + sqft_living + view + condition', data=df).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     9234.
# Date:                Tue, 05 Mar 2019   Prob (F-statistic):               0.00
# Time:                        17:47:24   Log-Likelihood:                -23390.
# No. Observations:               21613   AIC:                         4.679e+04
# Df Residuals:                   21608   BIC:                         4.683e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       6.4268      0.029    220.704      0.000       6.370       6.484
# ...

# %%
result = smf.ols('grade ~ price + sqft_living + condition', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                 1.230e+04
# Date:                Tue, 05 Mar 2019   Prob (F-statistic):               0.00
# Time:                        17:47:24   Log-Likelihood:                -23396.
# No. Observations:               21613   AIC:                         4.680e+04
# Df Residuals:                   21609   BIC:                         4.683e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       6.4355      0.029    221.758      0.000       6.379       6.492
# ...

# %%
result = smf.ols('grade ~ price + view + condition', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.474
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     6494.
# Date:                Tue, 05 Mar 2019   Prob (F-statistic):               0.00
# Time:                        17:47:24   Log-Likelihood:                -27216.
# No. Observations:               21613   AIC:                         5.444e+04
# Df Residuals:                   21609   BIC:                         5.447e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.5286      0.032    235.770      0.000       7.466       7.591
# ...

# %%
result = smf.ols(formula='grade ~ price + sqft_living + view + condition - 1', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  grade   R-squared:                       0.972
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                 1.900e+05
# Date:                Tue, 05 Mar 2019   Prob (F-statistic):               0.00
# Time:                        17:50:12   Log-Likelihood:                -36141.
# No. Observations:               21613   AIC:                         7.229e+04
# Df Residuals:                   21609   BIC:                         7.232e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# price        4.949e-07    3.5e-08     14.136      0.000    4.26e-07    5.63e-07
# ...
